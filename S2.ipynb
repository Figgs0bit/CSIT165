# %% [markdown]
# <a href="https://colab.research.google.com/github/Figgs0bit/CSIT165/blob/main/S2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CSIT275 - S2
# Topic: Array / String
#
# Please provide (handwritten) answers to the following questions. Please note: If you know how to write and test (manually) the required code, that is great. If you don't know, you can ask the internet, AI, or your friend. Then, you need to handwrite the code manually, take a picture and copy/paste the image here.
# Please make sure to provide space and time complexities (big-Os) at the end of each code (your answer). You also must (hand)write "I know how to write this code!" at the end of each answer.
#
#
# 1. You are given two strings word1 and word2. Merge the strings by adding letters in alternating order, starting with word1. If a string is longer than the other, append the additional letters onto the end of the merged string.
#
#   Input: word1 = "abc", word2 = "pqr"
#   Output: "apbqcr"
#
#   Input: word1 = "ab", word2 = "pqrs"
#   Output: "apbqrs"
#
#
#
# 2. For two strings s and t, we say "t divides s" if s = t + t + ... + t (t concatenated with itself one or more times). Given two strings str1 and str2, return the largest string x such that x divides both str1 and str2.
#
#   Input: str1 = "ABCABC", str2 = "ABC"
#   Output: "ABC"
#
#   Input: str1 = "ABABAB", str2 = "ABAB"
#   Output: "AB"
#
#
#
# 3. There are n kids with candies. You are given an integer array candies, where each candies[i] represents the number of candies the ith kid has, and an integer extraCandies. Return a boolean array result of length n, where result[i] is true if, after giving the ith kid all the extraCandies, they will have the greatest number of candies among all the kids, or false otherwise.
#
#   Input: candies = [2, 3, 5, 1, 3], extraCandies = 3
#   Output: [true, true, true, false, true]
#
#
#
# 4. You have a long flowerbed in which some of the plots are planted, and some are not. Flowers cannot be planted in adjacent plots. Given an integer array flowerbed containing 0's and 1's (0 means empty, 1 means not empty), and an integer n, return true if n new flowers can be planted in the flowerbed without violating the no-adjacent-flowers rule, and false otherwise.
#
#   Input: flowerbed = [1, 0, 0, 0, 1], n = 1
#   Output: true
#
#   Input: flowerbed = [1, 0, 0, 0, 1], n = 2
#   Output: false
#
#
#
# 5. Given a string s, reverse only all the vowels in the string and return it. The vowels are 'a', 'e', 'i', 'o', and 'u', and they can appear in both lower and upper cases.
#
#   Input: s = "IcesCreAm"
#   Output: "AcseCriIm"
#
#
#
# 6. Given an input string s, reverse the order of the words. A word is defined as a sequence of non-space characters. The words in s will be separated by at least one space. Return a string of the words in reverse order concatenated by a single space.
#
#   Input: s = "the sky is blue"
#   Output: "blue is sky the"
#
#   Input: s = "  hello world  "
#   Output: "world hello"
#
#
#
# 7. Given an integer array nums, return an array answer such that answer[i] is equal to the product of all the elements of nums except nums[i]. You must write an algorithm that runs in O(n) time and without using the division operation.
#
#   Input: nums = [1, 2, 3, 4]
#   Output: [24, 12, 8, 6]
#
#   Input: nums = [-1, 1, 0, -3, 3]
#   Output: [0, 0, 9, 0, 0]
#
#
#
# 8. Given an array of characters chars, compress it in-place. The length after compression must always be smaller than or equal to the original array. Each group of consecutive repeating characters is replaced by the character followed by the count (if count > 1). Return the new length of the array.
#
#   Input: chars = ["a","a","b","b","c","c","c"]
#   Output: Return 6, chars = ["a","2","b","2","c","3"]
#
#   Input: chars = ["a"]
#   Output: Return 1, chars = ["a"]
#
#
#
# Grade: 2
# The grade is effort-based. It is ok if your code is not written in the most efficient way, but every question must be answered.
#
# Submission
# Please rename this file to CSIT275-S2_<YourLastName>.docx and submit it to the Canvas CSIT275-S2 dropbox.
# For example, if I submit this assignment, the file name will be CSIT275-S2_Abla.docx
# The grade is effort-based. Your code does not need to be the most efficient solution, but every question must be answered.
